# %% [markdown]
# ## Downloading Wico Dataset Uploaded On Kaggle

# %%
# !pip install -q kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d manaspp/wico-graph
! unzip wico-graph
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Non_Conspiracy_Graphs/2286/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2286/plot.png
#   inflating: Non_Conspiracy_Graphs/2287/edges.txt
#   inflating: Non_Conspiracy_Graphs/2287/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2287/plot.png
#   inflating: Non_Conspiracy_Graphs/2288/edges.txt
#   inflating: Non_Conspiracy_Graphs/2288/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2288/plot.png
#   inflating: Non_Conspiracy_Graphs/2289/edges.txt
#   inflating: Non_Conspiracy_Graphs/2289/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2289/plot.png
#   inflating: Non_Conspiracy_Graphs/229/edges.txt
#   inflating: Non_Conspiracy_Graphs/229/nodes.csv
#   inflating: Non_Conspiracy_Graphs/229/plot.png
#   inflating: Non_Conspiracy_Graphs/2290/edges.txt
#   inflating: Non_Conspiracy_Graphs/2290/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2290/plot.png
#   inflating: Non_Conspiracy_Graphs/2291/edges.txt
#   inflating: Non_Conspiracy_Graphs/2291/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2291/plot.png
#   inflating: Non_Conspiracy_Graphs/2292/edges.txt
#   inflating: Non_Conspiracy_Graphs/2292/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2292/plot.png
#   inflating: Non_Conspiracy_Graphs/2293/edges.txt
#   inflating: Non_Conspiracy_Graphs/2293/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2293/plot.png
#   inflating: Non_Conspiracy_Graphs/2294/edges.txt
#   inflating: Non_Conspiracy_Graphs/2294/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2294/plot.png
#   inflating: Non_Conspiracy_Graphs/2295/edges.txt
#   inflating: Non_Conspiracy_Graphs/2295/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2295/plot.png
#   inflating: Non_Conspiracy_Graphs/2296/edges.txt
#   inflating: Non_Conspiracy_Graphs/2296/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2296/plot.png
#   inflating: Non_Conspiracy_Graphs/2297/edges.txt
#   inflating: Non_Conspiracy_Graphs/2297/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2297/plot.png
#   inflating: Non_Conspiracy_Graphs/2298/edges.txt
#   inflating: Non_Conspiracy_Graphs/2298/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2298/plot.png
#   inflating: Non_Conspiracy_Graphs/2299/edges.txt
#   inflating: Non_Conspiracy_Graphs/2299/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2299/plot.png
#   inflating: Non_Conspiracy_Graphs/23/edges.txt
#   inflating: Non_Conspiracy_Graphs/23/nodes.csv
#   inflating: Non_Conspiracy_Graphs/23/plot.png
#   inflating: Non_Conspiracy_Graphs/230/edges.txt
#   inflating: Non_Conspiracy_Graphs/230/nodes.csv
#   inflating: Non_Conspiracy_Graphs/230/plot.png
#   inflating: Non_Conspiracy_Graphs/2300/edges.txt
#   inflating: Non_Conspiracy_Graphs/2300/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2300/plot.png
#   inflating: Non_Conspiracy_Graphs/2301/edges.txt
#   inflating: Non_Conspiracy_Graphs/2301/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2301/plot.png
#   inflating: Non_Conspiracy_Graphs/2302/edges.txt
#   inflating: Non_Conspiracy_Graphs/2302/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2302/plot.png
#   inflating: Non_Conspiracy_Graphs/2303/edges.txt
#   inflating: Non_Conspiracy_Graphs/2303/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2303/plot.png
#   inflating: Non_Conspiracy_Graphs/2304/edges.txt
#   inflating: Non_Conspiracy_Graphs/2304/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2304/plot.png
#   inflating: Non_Conspiracy_Graphs/2305/edges.txt
#   inflating: Non_Conspiracy_Graphs/2305/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2305/plot.png
#   inflating: Non_Conspiracy_Graphs/2306/edges.txt
#   inflating: Non_Conspiracy_Graphs/2306/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2306/plot.png
#   inflating: Non_Conspiracy_Graphs/2307/edges.txt
#   inflating: Non_Conspiracy_Graphs/2307/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2307/plot.png
#   inflating: Non_Conspiracy_Graphs/2308/edges.txt
#   inflating: Non_Conspiracy_Graphs/2308/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2308/plot.png
#   inflating: Non_Conspiracy_Graphs/2309/edges.txt
#   inflating: Non_Conspiracy_Graphs/2309/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2309/plot.png
#   inflating: Non_Conspiracy_Graphs/231/edges.txt
#   inflating: Non_Conspiracy_Graphs/231/nodes.csv
#   inflating: Non_Conspiracy_Graphs/231/plot.png
#   inflating: Non_Conspiracy_Graphs/2310/edges.txt
#   inflating: Non_Conspiracy_Graphs/2310/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2310/plot.png
#   inflating: Non_Conspiracy_Graphs/2311/edges.txt
#   inflating: Non_Conspiracy_Graphs/2311/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2311/plot.png
#   inflating: Non_Conspiracy_Graphs/2312/edges.txt
#   inflating: Non_Conspiracy_Graphs/2312/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2312/plot.png
#   inflating: Non_Conspiracy_Graphs/2313/edges.txt
#   inflating: Non_Conspiracy_Graphs/2313/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2313/plot.png
#   inflating: Non_Conspiracy_Graphs/2314/edges.txt
#   inflating: Non_Conspiracy_Graphs/2314/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2314/plot.png
#   inflating: Non_Conspiracy_Graphs/2315/edges.txt
#   inflating: Non_Conspiracy_Graphs/2315/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2315/plot.png
#   inflating: Non_Conspiracy_Graphs/2316/edges.txt
#   inflating: Non_Conspiracy_Graphs/2316/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2316/plot.png
#   inflating: Non_Conspiracy_Graphs/2317/edges.txt
#   inflating: Non_Conspiracy_Graphs/2317/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2317/plot.png
#   inflating: Non_Conspiracy_Graphs/2318/edges.txt
#   inflating: Non_Conspiracy_Graphs/2318/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2318/plot.png
#   inflating: Non_Conspiracy_Graphs/2319/edges.txt
#   inflating: Non_Conspiracy_Graphs/2319/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2319/plot.png
#   inflating: Non_Conspiracy_Graphs/232/edges.txt
#   inflating: Non_Conspiracy_Graphs/232/nodes.csv
#   inflating: Non_Conspiracy_Graphs/232/plot.png
#   inflating: Non_Conspiracy_Graphs/2320/edges.txt
#   inflating: Non_Conspiracy_Graphs/2320/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2320/plot.png
#   inflating: Non_Conspiracy_Graphs/2321/edges.txt
#   inflating: Non_Conspiracy_Graphs/2321/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2321/plot.png
#   inflating: Non_Conspiracy_Graphs/2322/edges.txt
#   inflating: Non_Conspiracy_Graphs/2322/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2322/plot.png
#   inflating: Non_Conspiracy_Graphs/2323/edges.txt
#   inflating: Non_Conspiracy_Graphs/2323/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2323/plot.png
#   inflating: Non_Conspiracy_Graphs/2324/edges.txt
#   inflating: Non_Conspiracy_Graphs/2324/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2324/plot.png
#   inflating: Non_Conspiracy_Graphs/2325/edges.txt
#   inflating: Non_Conspiracy_Graphs/2325/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2325/plot.png
#   inflating: Non_Conspiracy_Graphs/2326/edges.txt
#   inflating: Non_Conspiracy_Graphs/2326/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2326/plot.png
#   inflating: Non_Conspiracy_Graphs/2327/edges.txt
#   inflating: Non_Conspiracy_Graphs/2327/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2327/plot.png
#   inflating: Non_Conspiracy_Graphs/2328/edges.txt
#   inflating: Non_Conspiracy_Graphs/2328/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2328/plot.png
#   inflating: Non_Conspiracy_Graphs/2329/edges.txt
#   inflating: Non_Conspiracy_Graphs/2329/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2329/plot.png
#   inflating: Non_Conspiracy_Graphs/233/edges.txt
#   inflating: Non_Conspiracy_Graphs/233/nodes.csv
#   inflating: Non_Conspiracy_Graphs/233/plot.png
#   inflating: Non_Conspiracy_Graphs/2330/edges.txt
#   inflating: Non_Conspiracy_Graphs/2330/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2330/plot.png
#   inflating: Non_Conspiracy_Graphs/2331/edges.txt
#   inflating: Non_Conspiracy_Graphs/2331/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2331/plot.png
#   inflating: Non_Conspiracy_Graphs/2332/edges.txt
#   inflating: Non_Conspiracy_Graphs/2332/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2332/plot.png
#   inflating: Non_Conspiracy_Graphs/2333/edges.txt
#   inflating: Non_Conspiracy_Graphs/2333/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2333/plot.png
#   inflating: Non_Conspiracy_Graphs/2334/edges.txt
#   inflating: Non_Conspiracy_Graphs/2334/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2334/plot.png
#   inflating: Non_Conspiracy_Graphs/2335/edges.txt
#   inflating: Non_Conspiracy_Graphs/2335/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2335/plot.png
#   inflating: Non_Conspiracy_Graphs/2336/edges.txt
#   inflating: Non_Conspiracy_Graphs/2336/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2336/plot.png
#   inflating: Non_Conspiracy_Graphs/2337/edges.txt
#   inflating: Non_Conspiracy_Graphs/2337/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2337/plot.png
#   inflating: Non_Conspiracy_Graphs/2338/edges.txt
#   inflating: Non_Conspiracy_Graphs/2338/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2338/plot.png
#   inflating: Non_Conspiracy_Graphs/2339/edges.txt
#   inflating: Non_Conspiracy_Graphs/2339/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2339/plot.png
#   inflating: Non_Conspiracy_Graphs/234/edges.txt
#   inflating: Non_Conspiracy_Graphs/234/nodes.csv
#   inflating: Non_Conspiracy_Graphs/234/plot.png
#   inflating: Non_Conspiracy_Graphs/2340/edges.txt
#   inflating: Non_Conspiracy_Graphs/2340/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2340/plot.png
#   inflating: Non_Conspiracy_Graphs/2341/edges.txt
#   inflating: Non_Conspiracy_Graphs/2341/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2341/plot.png
#   inflating: Non_Conspiracy_Graphs/2342/edges.txt
#   inflating: Non_Conspiracy_Graphs/2342/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2342/plot.png
#   inflating: Non_Conspiracy_Graphs/2343/edges.txt
#   inflating: Non_Conspiracy_Graphs/2343/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2343/plot.png
#   inflating: Non_Conspiracy_Graphs/2344/edges.txt
#   inflating: Non_Conspiracy_Graphs/2344/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2344/plot.png
#   inflating: Non_Conspiracy_Graphs/2345/edges.txt
#   inflating: Non_Conspiracy_Graphs/2345/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2345/plot.png
#   inflating: Non_Conspiracy_Graphs/2346/edges.txt
#   inflating: Non_Conspiracy_Graphs/2346/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2346/plot.png
#   inflating: Non_Conspiracy_Graphs/2347/edges.txt
#   inflating: Non_Conspiracy_Graphs/2347/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2347/plot.png
#   inflating: Non_Conspiracy_Graphs/2348/edges.txt
#   inflating: Non_Conspiracy_Graphs/2348/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2348/plot.png
#   inflating: Non_Conspiracy_Graphs/2349/edges.txt
#   inflating: Non_Conspiracy_Graphs/2349/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2349/plot.png
#   inflating: Non_Conspiracy_Graphs/235/edges.txt
#   inflating: Non_Conspiracy_Graphs/235/nodes.csv
#   inflating: Non_Conspiracy_Graphs/235/plot.png
#   inflating: Non_Conspiracy_Graphs/2350/edges.txt
#   inflating: Non_Conspiracy_Graphs/2350/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2350/plot.png
#   inflating: Non_Conspiracy_Graphs/2351/edges.txt
#   inflating: Non_Conspiracy_Graphs/2351/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2351/plot.png
#   inflating: Non_Conspiracy_Graphs/2352/edges.txt
#   inflating: Non_Conspiracy_Graphs/2352/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2352/plot.png
#   inflating: Non_Conspiracy_Graphs/2353/edges.txt
#   inflating: Non_Conspiracy_Graphs/2353/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2353/plot.png
#   inflating: Non_Conspiracy_Graphs/2354/edges.txt
#   inflating: Non_Conspiracy_Graphs/2354/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2354/plot.png
#   inflating: Non_Conspiracy_Graphs/2355/edges.txt
#   inflating: Non_Conspiracy_Graphs/2355/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2355/plot.png
#   inflating: Non_Conspiracy_Graphs/2356/edges.txt
#   inflating: Non_Conspiracy_Graphs/2356/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2356/plot.png
#   inflating: Non_Conspiracy_Graphs/2357/edges.txt
#   inflating: Non_Conspiracy_Graphs/2357/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2357/plot.png
#   inflating: Non_Conspiracy_Graphs/2358/edges.txt
#   inflating: Non_Conspiracy_Graphs/2358/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2358/plot.png
#   inflating: Non_Conspiracy_Graphs/2359/edges.txt
#   inflating: Non_Conspiracy_Graphs/2359/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2359/plot.png
#   inflating: Non_Conspiracy_Graphs/236/edges.txt
#   inflating: Non_Conspiracy_Graphs/236/nodes.csv
#   inflating: Non_Conspiracy_Graphs/236/plot.png
#   inflating: Non_Conspiracy_Graphs/2360/edges.txt
#   inflating: Non_Conspiracy_Graphs/2360/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2360/plot.png
#   inflating: Non_Conspiracy_Graphs/2361/edges.txt
#   inflating: Non_Conspiracy_Graphs/2361/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2361/plot.png
#   inflating: Non_Conspiracy_Graphs/2362/edges.txt
#   inflating: Non_Conspiracy_Graphs/2362/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2362/plot.png
#   inflating: Non_Conspiracy_Graphs/2363/edges.txt
#   inflating: Non_Conspiracy_Graphs/2363/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2363/plot.png
#   inflating: Non_Conspiracy_Graphs/2364/edges.txt
#   inflating: Non_Conspiracy_Graphs/2364/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2364/plot.png
#   inflating: Non_Conspiracy_Graphs/2365/edges.txt
#   inflating: Non_Conspiracy_Graphs/2365/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2365/plot.png
#   inflating: Non_Conspiracy_Graphs/2366/edges.txt
#   inflating: Non_Conspiracy_Graphs/2366/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2366/plot.png
#   inflating: Non_Conspiracy_Graphs/2367/edges.txt
#   inflating: Non_Conspiracy_Graphs/2367/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2367/plot.png
#   inflating: Non_Conspiracy_Graphs/2368/edges.txt
#   inflating: Non_Conspiracy_Graphs/2368/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2368/plot.png
#   inflating: Non_Conspiracy_Graphs/2369/edges.txt
#   inflating: Non_Conspiracy_Graphs/2369/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2369/plot.png
#   inflating: Non_Conspiracy_Graphs/237/edges.txt
#   inflating: Non_Conspiracy_Graphs/237/nodes.csv
#   inflating: Non_Conspiracy_Graphs/237/plot.png
#   inflating: Non_Conspiracy_Graphs/2370/edges.txt
#   inflating: Non_Conspiracy_Graphs/2370/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2370/plot.png
#   inflating: Non_Conspiracy_Graphs/2371/edges.txt
#   inflating: Non_Conspiracy_Graphs/2371/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2371/plot.png
#   inflating: Non_Conspiracy_Graphs/2372/edges.txt
#   inflating: Non_Conspiracy_Graphs/2372/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2372/plot.png
#   inflating: Non_Conspiracy_Graphs/2373/edges.txt
#   inflating: Non_Conspiracy_Graphs/2373/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2373/plot.png
#   inflating: Non_Conspiracy_Graphs/2374/edges.txt
#   inflating: Non_Conspiracy_Graphs/2374/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2374/plot.png
#   inflating: Non_Conspiracy_Graphs/2375/edges.txt
#   inflating: Non_Conspiracy_Graphs/2375/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2375/plot.png
#   inflating: Non_Conspiracy_Graphs/2376/edges.txt
#   inflating: Non_Conspiracy_Graphs/2376/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2376/plot.png
#   inflating: Non_Conspiracy_Graphs/2377/edges.txt
#   inflating: Non_Conspiracy_Graphs/2377/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2377/plot.png
#   inflating: Non_Conspiracy_Graphs/2378/edges.txt
#   inflating: Non_Conspiracy_Graphs/2378/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2378/plot.png
#   inflating: Non_Conspiracy_Graphs/2379/edges.txt
#   inflating: Non_Conspiracy_Graphs/2379/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2379/plot.png
#   inflating: Non_Conspiracy_Graphs/238/edges.txt
#   inflating: Non_Conspiracy_Graphs/238/nodes.csv
#   inflating: Non_Conspiracy_Graphs/238/plot.png
#   inflating: Non_Conspiracy_Graphs/2380/edges.txt
#   inflating: Non_Conspiracy_Graphs/2380/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2381/edges.txt
#   inflating: Non_Conspiracy_Graphs/2381/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2381/plot.png
#   inflating: Non_Conspiracy_Graphs/2382/edges.txt
#   inflating: Non_Conspiracy_Graphs/2382/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2382/plot.png
#   inflating: Non_Conspiracy_Graphs/2383/edges.txt
#   inflating: Non_Conspiracy_Graphs/2383/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2383/plot.png
#   inflating: Non_Conspiracy_Graphs/2384/edges.txt
#   inflating: Non_Conspiracy_Graphs/2384/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2384/plot.png
#   inflating: Non_Conspiracy_Graphs/2385/edges.txt
#   inflating: Non_Conspiracy_Graphs/2385/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2385/plot.png
#   inflating: Non_Conspiracy_Graphs/2386/edges.txt
#   inflating: Non_Conspiracy_Graphs/2386/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2386/plot.png
#   inflating: Non_Conspiracy_Graphs/2387/edges.txt
#   inflating: Non_Conspiracy_Graphs/2387/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2387/plot.png
#   inflating: Non_Conspiracy_Graphs/2388/edges.txt
#   inflating: Non_Conspiracy_Graphs/2388/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2388/plot.png
#   inflating: Non_Conspiracy_Graphs/2389/edges.txt
#   inflating: Non_Conspiracy_Graphs/2389/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2389/plot.png
#   inflating: Non_Conspiracy_Graphs/239/edges.txt
#   inflating: Non_Conspiracy_Graphs/239/nodes.csv
#   inflating: Non_Conspiracy_Graphs/239/plot.png
#   inflating: Non_Conspiracy_Graphs/2390/edges.txt
#   inflating: Non_Conspiracy_Graphs/2390/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2390/plot.png
#   inflating: Non_Conspiracy_Graphs/2391/edges.txt
#   inflating: Non_Conspiracy_Graphs/2391/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2391/plot.png
#   inflating: Non_Conspiracy_Graphs/2392/edges.txt
#   inflating: Non_Conspiracy_Graphs/2392/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2392/plot.png
#   inflating: Non_Conspiracy_Graphs/2393/edges.txt
#   inflating: Non_Conspiracy_Graphs/2393/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2393/plot.png
#   inflating: Non_Conspiracy_Graphs/2394/edges.txt
#   inflating: Non_Conspiracy_Graphs/2394/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2394/plot.png
#   inflating: Non_Conspiracy_Graphs/2395/edges.txt
#   inflating: Non_Conspiracy_Graphs/2395/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2395/plot.png
#   inflating: Non_Conspiracy_Graphs/2396/edges.txt
#   inflating: Non_Conspiracy_Graphs/2396/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2396/plot.png
#   inflating: Non_Conspiracy_Graphs/2397/edges.txt
#   inflating: Non_Conspiracy_Graphs/2397/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2397/plot.png
#   inflating: Non_Conspiracy_Graphs/2398/edges.txt
#   inflating: Non_Conspiracy_Graphs/2398/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2398/plot.png
#   inflating: Non_Conspiracy_Graphs/2399/edges.txt
#   inflating: Non_Conspiracy_Graphs/2399/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2399/plot.png
#   inflating: Non_Conspiracy_Graphs/24/edges.txt
#   inflating: Non_Conspiracy_Graphs/24/nodes.csv
#   inflating: Non_Conspiracy_Graphs/24/plot.png
#   inflating: Non_Conspiracy_Graphs/240/edges.txt
#   inflating: Non_Conspiracy_Graphs/240/nodes.csv
#   inflating: Non_Conspiracy_Graphs/240/plot.png
#   inflating: Non_Conspiracy_Graphs/2400/edges.txt
#   inflating: Non_Conspiracy_Graphs/2400/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2400/plot.png
#   inflating: Non_Conspiracy_Graphs/2401/edges.txt
#   inflating: Non_Conspiracy_Graphs/2401/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2401/plot.png
#   inflating: Non_Conspiracy_Graphs/2402/edges.txt
#   inflating: Non_Conspiracy_Graphs/2402/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2402/plot.png
#   inflating: Non_Conspiracy_Graphs/2403/edges.txt
#   inflating: Non_Conspiracy_Graphs/2403/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2403/plot.png
#   inflating: Non_Conspiracy_Graphs/2404/edges.txt
#   inflating: Non_Conspiracy_Graphs/2404/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2404/plot.png
#   inflating: Non_Conspiracy_Graphs/2405/edges.txt
#   inflating: Non_Conspiracy_Graphs/2405/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2405/plot.png
#   inflating: Non_Conspiracy_Graphs/2406/edges.txt
#   inflating: Non_Conspiracy_Graphs/2406/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2406/plot.png
#   inflating: Non_Conspiracy_Graphs/2407/edges.txt
#   inflating: Non_Conspiracy_Graphs/2407/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2407/plot.png
#   inflating: Non_Conspiracy_Graphs/2408/edges.txt
#   inflating: Non_Conspiracy_Graphs/2408/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2408/plot.png
#   inflating: Non_Conspiracy_Graphs/2409/edges.txt
#   inflating: Non_Conspiracy_Graphs/2409/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2409/plot.png
#   inflating: Non_Conspiracy_Graphs/241/edges.txt
#   inflating: Non_Conspiracy_Graphs/241/nodes.csv
#   inflating: Non_Conspiracy_Graphs/241/plot.png
#   inflating: Non_Conspiracy_Graphs/2410/edges.txt
#   inflating: Non_Conspiracy_Graphs/2410/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2410/plot.png
#   inflating: Non_Conspiracy_Graphs/2411/edges.txt
#   inflating: Non_Conspiracy_Graphs/2411/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2411/plot.png
#   inflating: Non_Conspiracy_Graphs/2412/edges.txt
#   inflating: Non_Conspiracy_Graphs/2412/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2412/plot.png
#   inflating: Non_Conspiracy_Graphs/2413/edges.txt
#   inflating: Non_Conspiracy_Graphs/2413/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2413/plot.png
#   inflating: Non_Conspiracy_Graphs/2414/edges.txt
#   inflating: Non_Conspiracy_Graphs/2414/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2414/plot.png
#   inflating: Non_Conspiracy_Graphs/2415/edges.txt
#   inflating: Non_Conspiracy_Graphs/2415/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2415/plot.png
#   inflating: Non_Conspiracy_Graphs/2416/edges.txt
#   inflating: Non_Conspiracy_Graphs/2416/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2416/plot.png
#   inflating: Non_Conspiracy_Graphs/2417/edges.txt
#   inflating: Non_Conspiracy_Graphs/2417/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2417/plot.png
#   inflating: Non_Conspiracy_Graphs/2418/edges.txt
#   inflating: Non_Conspiracy_Graphs/2418/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2418/plot.png
#   inflating: Non_Conspiracy_Graphs/2419/edges.txt
#   inflating: Non_Conspiracy_Graphs/2419/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2419/plot.png
#   inflating: Non_Conspiracy_Graphs/242/edges.txt
#   inflating: Non_Conspiracy_Graphs/242/nodes.csv
#   inflating: Non_Conspiracy_Graphs/242/plot.png
#   inflating: Non_Conspiracy_Graphs/2420/edges.txt
#   inflating: Non_Conspiracy_Graphs/2420/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2420/plot.png
#   inflating: Non_Conspiracy_Graphs/2421/edges.txt
#   inflating: Non_Conspiracy_Graphs/2421/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2421/plot.png
#   inflating: Non_Conspiracy_Graphs/2422/edges.txt
#   inflating: Non_Conspiracy_Graphs/2422/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2422/plot.png
#   inflating: Non_Conspiracy_Graphs/2423/edges.txt
#   inflating: Non_Conspiracy_Graphs/2423/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2423/plot.png
#   inflating: Non_Conspiracy_Graphs/2424/edges.txt
#   inflating: Non_Conspiracy_Graphs/2424/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2424/plot.png
#   inflating: Non_Conspiracy_Graphs/2425/edges.txt
#   inflating: Non_Conspiracy_Graphs/2425/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2425/plot.png
#   inflating: Non_Conspiracy_Graphs/2426/edges.txt
#   inflating: Non_Conspiracy_Graphs/2426/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2426/plot.png
#   inflating: Non_Conspiracy_Graphs/2427/edges.txt
#   inflating: Non_Conspiracy_Graphs/2427/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2427/plot.png
#   inflating: Non_Conspiracy_Graphs/2428/edges.txt
#   inflating: Non_Conspiracy_Graphs/2428/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2428/plot.png
#   inflating: Non_Conspiracy_Graphs/2429/edges.txt
#   inflating: Non_Conspiracy_Graphs/2429/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2429/plot.png
#   inflating: Non_Conspiracy_Graphs/243/edges.txt
#   inflating: Non_Conspiracy_Graphs/243/nodes.csv
#   inflating: Non_Conspiracy_Graphs/243/plot.png
#   inflating: Non_Conspiracy_Graphs/2430/edges.txt
#   inflating: Non_Conspiracy_Graphs/2430/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2430/plot.png
#   inflating: Non_Conspiracy_Graphs/2431/edges.txt
#   inflating: Non_Conspiracy_Graphs/2431/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2431/plot.png
#   inflating: Non_Conspiracy_Graphs/2432/edges.txt
#   inflating: Non_Conspiracy_Graphs/2432/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2432/plot.png
#   inflating: Non_Conspiracy_Graphs/2433/edges.txt
#   inflating: Non_Conspiracy_Graphs/2433/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2433/plot.png
#   inflating: Non_Conspiracy_Graphs/2434/edges.txt
#   inflating: Non_Conspiracy_Graphs/2434/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2434/plot.png
#   inflating: Non_Conspiracy_Graphs/2435/edges.txt
#   inflating: Non_Conspiracy_Graphs/2435/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2435/plot.png
#   inflating: Non_Conspiracy_Graphs/2436/edges.txt
#   inflating: Non_Conspiracy_Graphs/2436/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2436/plot.png
#   inflating: Non_Conspiracy_Graphs/2437/edges.txt
#   inflating: Non_Conspiracy_Graphs/2437/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2437/plot.png
#   inflating: Non_Conspiracy_Graphs/2438/edges.txt
#   inflating: Non_Conspiracy_Graphs/2438/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2438/plot.png
#   inflating: Non_Conspiracy_Graphs/2439/edges.txt
#   inflating: Non_Conspiracy_Graphs/2439/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2439/plot.png
#   inflating: Non_Conspiracy_Graphs/244/edges.txt
#   inflating: Non_Conspiracy_Graphs/244/nodes.csv
#   inflating: Non_Conspiracy_Graphs/244/plot.png
#   inflating: Non_Conspiracy_Graphs/2440/edges.txt
#   inflating: Non_Conspiracy_Graphs/2440/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2440/plot.png
#   inflating: Non_Conspiracy_Graphs/2441/edges.txt
#   inflating: Non_Conspiracy_Graphs/2441/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2441/plot.png
#   inflating: Non_Conspiracy_Graphs/2442/edges.txt
#   inflating: Non_Conspiracy_Graphs/2442/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2442/plot.png
#   inflating: Non_Conspiracy_Graphs/2443/edges.txt
#   inflating: Non_Conspiracy_Graphs/2443/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2443/plot.png
#   inflating: Non_Conspiracy_Graphs/2444/edges.txt
#   inflating: Non_Conspiracy_Graphs/2444/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2444/plot.png
#   inflating: Non_Conspiracy_Graphs/2445/edges.txt
#   inflating: Non_Conspiracy_Graphs/2445/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2445/plot.png
#   inflating: Non_Conspiracy_Graphs/2446/edges.txt
#   inflating: Non_Conspiracy_Graphs/2446/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2446/plot.png
#   inflating: Non_Conspiracy_Graphs/2447/edges.txt
#   inflating: Non_Conspiracy_Graphs/2447/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2447/plot.png
#   inflating: Non_Conspiracy_Graphs/2448/edges.txt
#   inflating: Non_Conspiracy_Graphs/2448/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2448/plot.png
#   inflating: Non_Conspiracy_Graphs/2449/edges.txt
#   inflating: Non_Conspiracy_Graphs/2449/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2449/plot.png
#   inflating: Non_Conspiracy_Graphs/245/edges.txt
#   inflating: Non_Conspiracy_Graphs/245/nodes.csv
#   inflating: Non_Conspiracy_Graphs/245/plot.png
#   inflating: Non_Conspiracy_Graphs/2450/edges.txt
#   inflating: Non_Conspiracy_Graphs/2450/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2450/plot.png
#   inflating: Non_Conspiracy_Graphs/2451/edges.txt
#   inflating: Non_Conspiracy_Graphs/2451/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2451/plot.png
#   inflating: Non_Conspiracy_Graphs/2452/edges.txt
#   inflating: Non_Conspiracy_Graphs/2452/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2452/plot.png
#   inflating: Non_Conspiracy_Graphs/2453/edges.txt
#   inflating: Non_Conspiracy_Graphs/2453/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2453/plot.png
#   inflating: Non_Conspiracy_Graphs/2454/edges.txt
#   inflating: Non_Conspiracy_Graphs/2454/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2454/plot.png
#   inflating: Non_Conspiracy_Graphs/2455/edges.txt
#   inflating: Non_Conspiracy_Graphs/2455/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2455/plot.png
#   inflating: Non_Conspiracy_Graphs/2456/edges.txt
#   inflating: Non_Conspiracy_Graphs/2456/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2456/plot.png
#   inflating: Non_Conspiracy_Graphs/2457/edges.txt
#   inflating: Non_Conspiracy_Graphs/2457/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2457/plot.png
#   inflating: Non_Conspiracy_Graphs/2458/edges.txt
#   inflating: Non_Conspiracy_Graphs/2458/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2458/plot.png
#   inflating: Non_Conspiracy_Graphs/2459/edges.txt
#   inflating: Non_Conspiracy_Graphs/2459/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2459/plot.png
#   inflating: Non_Conspiracy_Graphs/246/edges.txt
#   inflating: Non_Conspiracy_Graphs/246/nodes.csv
#   inflating: Non_Conspiracy_Graphs/246/plot.png
#   inflating: Non_Conspiracy_Graphs/2460/edges.txt
#   inflating: Non_Conspiracy_Graphs/2460/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2460/plot.png
#   inflating: Non_Conspiracy_Graphs/2461/edges.txt
#   inflating: Non_Conspiracy_Graphs/2461/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2461/plot.png
#   inflating: Non_Conspiracy_Graphs/2462/edges.txt
#   inflating: Non_Conspiracy_Graphs/2462/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2462/plot.png
#   inflating: Non_Conspiracy_Graphs/2463/edges.txt
#   inflating: Non_Conspiracy_Graphs/2463/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2463/plot.png
#   inflating: Non_Conspiracy_Graphs/2464/edges.txt
#   inflating: Non_Conspiracy_Graphs/2464/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2464/plot.png
#   inflating: Non_Conspiracy_Graphs/2465/edges.txt
#   inflating: Non_Conspiracy_Graphs/2465/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2465/plot.png
#   inflating: Non_Conspiracy_Graphs/2466/edges.txt
#   inflating: Non_Conspiracy_Graphs/2466/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2466/plot.png
#   inflating: Non_Conspiracy_Graphs/2467/edges.txt
#   inflating: Non_Conspiracy_Graphs/2467/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2467/plot.png
#   inflating: Non_Conspiracy_Graphs/2468/edges.txt
#   inflating: Non_Conspiracy_Graphs/2468/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2468/plot.png
#   inflating: Non_Conspiracy_Graphs/2469/edges.txt
#   inflating: Non_Conspiracy_Graphs/2469/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2469/plot.png
#   inflating: Non_Conspiracy_Graphs/247/edges.txt
#   inflating: Non_Conspiracy_Graphs/247/nodes.csv
#   inflating: Non_Conspiracy_Graphs/247/plot.png
#   inflating: Non_Conspiracy_Graphs/2470/edges.txt
#   inflating: Non_Conspiracy_Graphs/2470/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2470/plot.png
#   inflating: Non_Conspiracy_Graphs/2471/edges.txt
#   inflating: Non_Conspiracy_Graphs/2471/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2471/plot.png
#   inflating: Non_Conspiracy_Graphs/2472/edges.txt
#   inflating: Non_Conspiracy_Graphs/2472/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2472/plot.png
#   inflating: Non_Conspiracy_Graphs/2473/edges.txt
#   inflating: Non_Conspiracy_Graphs/2473/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2473/plot.png
#   inflating: Non_Conspiracy_Graphs/2474/edges.txt
#   inflating: Non_Conspiracy_Graphs/2474/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2474/plot.png
#   inflating: Non_Conspiracy_Graphs/2475/edges.txt
#   inflating: Non_Conspiracy_Graphs/2475/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2475/plot.png
#   inflating: Non_Conspiracy_Graphs/2476/edges.txt
#   inflating: Non_Conspiracy_Graphs/2476/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2476/plot.png
#   inflating: Non_Conspiracy_Graphs/2477/edges.txt
#   inflating: Non_Conspiracy_Graphs/2477/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2477/plot.png
#   inflating: Non_Conspiracy_Graphs/2478/edges.txt
#   inflating: Non_Conspiracy_Graphs/2478/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2478/plot.png
#   inflating: Non_Conspiracy_Graphs/2479/edges.txt
#   inflating: Non_Conspiracy_Graphs/2479/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2479/plot.png
#   inflating: Non_Conspiracy_Graphs/248/edges.txt
#   inflating: Non_Conspiracy_Graphs/248/nodes.csv
#   inflating: Non_Conspiracy_Graphs/248/plot.png
#   inflating: Non_Conspiracy_Graphs/2480/edges.txt
#   inflating: Non_Conspiracy_Graphs/2480/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2480/plot.png
#   inflating: Non_Conspiracy_Graphs/2481/edges.txt
#   inflating: Non_Conspiracy_Graphs/2481/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2481/plot.png
#   inflating: Non_Conspiracy_Graphs/2482/edges.txt
#   inflating: Non_Conspiracy_Graphs/2482/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2482/plot.png
#   inflating: Non_Conspiracy_Graphs/2483/edges.txt
#   inflating: Non_Conspiracy_Graphs/2483/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2483/plot.png
#   inflating: Non_Conspiracy_Graphs/2484/edges.txt
#   inflating: Non_Conspiracy_Graphs/2484/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2485/edges.txt
#   inflating: Non_Conspiracy_Graphs/2485/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2485/plot.png
#   inflating: Non_Conspiracy_Graphs/2486/edges.txt
#   inflating: Non_Conspiracy_Graphs/2486/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2486/plot.png
#   inflating: Non_Conspiracy_Graphs/2487/edges.txt
#   inflating: Non_Conspiracy_Graphs/2487/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2487/plot.png
#   inflating: Non_Conspiracy_Graphs/2488/edges.txt
#   inflating: Non_Conspiracy_Graphs/2488/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2488/plot.png
#   inflating: Non_Conspiracy_Graphs/2489/edges.txt
#   inflating: Non_Conspiracy_Graphs/2489/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2489/plot.png
#   inflating: Non_Conspiracy_Graphs/249/edges.txt
#   inflating: Non_Conspiracy_Graphs/249/nodes.csv
#   inflating: Non_Conspiracy_Graphs/249/plot.png
#   inflating: Non_Conspiracy_Graphs/2490/edges.txt
#   inflating: Non_Conspiracy_Graphs/2490/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2490/plot.png
#   inflating: Non_Conspiracy_Graphs/2491/edges.txt
#   inflating: Non_Conspiracy_Graphs/2491/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2491/plot.png
#   inflating: Non_Conspiracy_Graphs/2492/edges.txt
#   inflating: Non_Conspiracy_Graphs/2492/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2492/plot.png
#   inflating: Non_Conspiracy_Graphs/2493/edges.txt
#   inflating: Non_Conspiracy_Graphs/2493/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2493/plot.png
#   inflating: Non_Conspiracy_Graphs/2494/edges.txt
#   inflating: Non_Conspiracy_Graphs/2494/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2494/plot.png
#   inflating: Non_Conspiracy_Graphs/2495/edges.txt
#   inflating: Non_Conspiracy_Graphs/2495/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2495/plot.png
#   inflating: Non_Conspiracy_Graphs/2496/edges.txt
#   inflating: Non_Conspiracy_Graphs/2496/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2496/plot.png
#   inflating: Non_Conspiracy_Graphs/2497/edges.txt
#   inflating: Non_Conspiracy_Graphs/2497/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2497/plot.png
#   inflating: Non_Conspiracy_Graphs/2498/edges.txt
#   inflating: Non_Conspiracy_Graphs/2498/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2498/plot.png
#   inflating: Non_Conspiracy_Graphs/2499/edges.txt
#   inflating: Non_Conspiracy_Graphs/2499/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2499/plot.png
#   inflating: Non_Conspiracy_Graphs/25/edges.txt
#   inflating: Non_Conspiracy_Graphs/25/nodes.csv
#   inflating: Non_Conspiracy_Graphs/25/plot.png
#   inflating: Non_Conspiracy_Graphs/250/edges.txt
#   inflating: Non_Conspiracy_Graphs/250/nodes.csv
#   inflating: Non_Conspiracy_Graphs/250/plot.png
#   inflating: Non_Conspiracy_Graphs/2500/edges.txt
#   inflating: Non_Conspiracy_Graphs/2500/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2500/plot.png
#   inflating: Non_Conspiracy_Graphs/2501/edges.txt
#   inflating: Non_Conspiracy_Graphs/2501/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2501/plot.png
#   inflating: Non_Conspiracy_Graphs/2502/edges.txt
#   inflating: Non_Conspiracy_Graphs/2502/nodes.csv
#   inflating: Non_Conspiracy_Graphs/2502/plot.png
#   inflating: Non_Conspiracy_Graphs/251/edges.txt
#   inflating: Non_Conspiracy_Graphs/251/nodes.csv
#   inflating: Non_Conspiracy_Graphs/251/plot.png
#   inflating: Non_Conspiracy_Graphs/252/edges.txt
#   inflating: Non_Conspiracy_Graphs/252/nodes.csv
#   inflating: Non_Conspiracy_Graphs/252/plot.png
#   inflating: Non_Conspiracy_Graphs/253/edges.txt
#   inflating: Non_Conspiracy_Graphs/253/nodes.csv
#   inflating: Non_Conspiracy_Graphs/253/plot.png
#   inflating: Non_Conspiracy_Graphs/254/edges.txt
#   inflating: Non_Conspiracy_Graphs/254/nodes.csv
#   inflating: Non_Conspiracy_Graphs/254/plot.png
#   inflating: Non_Conspiracy_Graphs/255/edges.txt
#   inflating: Non_Conspiracy_Graphs/255/nodes.csv
#   inflating: Non_Conspiracy_Graphs/255/plot.png
#   inflating: Non_Conspiracy_Graphs/256/edges.txt
#   inflating: Non_Conspiracy_Graphs/256/nodes.csv
#   inflating: Non_Conspiracy_Graphs/256/plot.png
#   inflating: Non_Conspiracy_Graphs/257/edges.txt
#   inflating: Non_Conspiracy_Graphs/257/nodes.csv
#   inflating: Non_Conspiracy_Graphs/257/plot.png
#   inflating: Non_Conspiracy_Graphs/258/edges.txt
#   inflating: Non_Conspiracy_Graphs/258/nodes.csv
#   inflating: Non_Conspiracy_Graphs/258/plot.png
#   inflating: Non_Conspiracy_Graphs/259/edges.txt
#   inflating: Non_Conspiracy_Graphs/259/nodes.csv
#   inflating: Non_Conspiracy_Graphs/259/plot.png
#   inflating: Non_Conspiracy_Graphs/26/edges.txt
#   inflating: Non_Conspiracy_Graphs/26/nodes.csv
#   inflating: Non_Conspiracy_Graphs/26/plot.png
#   inflating: Non_Conspiracy_Graphs/260/edges.txt
#   inflating: Non_Conspiracy_Graphs/260/nodes.csv
#   inflating: Non_Conspiracy_Graphs/260/plot.png
#   inflating: Non_Conspiracy_Graphs/261/edges.txt
#   inflating: Non_Conspiracy_Graphs/261/nodes.csv
#   inflating: Non_Conspiracy_Graphs/261/plot.png
#   inflating: Non_Conspiracy_Graphs/262/edges.txt
#   inflating: Non_Conspiracy_Graphs/262/nodes.csv
#   inflating: Non_Conspiracy_Graphs/262/plot.png
#   inflating: Non_Conspiracy_Graphs/263/edges.txt
#   inflating: Non_Conspiracy_Graphs/263/nodes.csv
#   inflating: Non_Conspiracy_Graphs/263/plot.png
#   inflating: Non_Conspiracy_Graphs/264/edges.txt
#   inflating: Non_Conspiracy_Graphs/264/nodes.csv
#   inflating: Non_Conspiracy_Graphs/264/plot.png
#   inflating: Non_Conspiracy_Graphs/265/edges.txt
#   inflating: Non_Conspiracy_Graphs/265/nodes.csv
#   inflating: Non_Conspiracy_Graphs/265/plot.png
#   inflating: Non_Conspiracy_Graphs/266/edges.txt
#   inflating: Non_Conspiracy_Graphs/266/nodes.csv
#   inflating: Non_Conspiracy_Graphs/266/plot.png
#   inflating: Non_Conspiracy_Graphs/267/edges.txt
#   inflating: Non_Conspiracy_Graphs/267/nodes.csv
#   inflating: Non_Conspiracy_Graphs/267/plot.png
#   inflating: Non_Conspiracy_Graphs/268/edges.txt
#   inflating: Non_Conspiracy_Graphs/268/nodes.csv
#   inflating: Non_Conspiracy_Graphs/268/plot.png
#   inflating: Non_Conspiracy_Graphs/269/edges.txt
#   inflating: Non_Conspiracy_Graphs/269/nodes.csv
#   inflating: Non_Conspiracy_Graphs/269/plot.png
#   inflating: Non_Conspiracy_Graphs/27/edges.txt
#   inflating: Non_Conspiracy_Graphs/27/nodes.csv
#   inflating: Non_Conspiracy_Graphs/27/plot.png
#   inflating: Non_Conspiracy_Graphs/270/edges.txt
#   inflating: Non_Conspiracy_Graphs/270/nodes.csv
#   inflating: Non_Conspiracy_Graphs/270/plot.png
#   inflating: Non_Conspiracy_Graphs/271/edges.txt
#   inflating: Non_Conspiracy_Graphs/271/nodes.csv
#   inflating: Non_Conspiracy_Graphs/271/plot.png
#   inflating: Non_Conspiracy_Graphs/272/edges.txt
#   inflating: Non_Conspiracy_Graphs/272/nodes.csv
#   inflating: Non_Conspiracy_Graphs/272/plot.png
#   inflating: Non_Conspiracy_Graphs/273/edges.txt
#   inflating: Non_Conspiracy_Graphs/273/nodes.csv
#   inflating: Non_Conspiracy_Graphs/273/plot.png
#   inflating: Non_Conspiracy_Graphs/274/edges.txt
#   inflating: Non_Conspiracy_Graphs/274/nodes.csv
#   inflating: Non_Conspiracy_Graphs/274/plot.png
#   inflating: Non_Conspiracy_Graphs/275/edges.txt
#   inflating: Non_Conspiracy_Graphs/275/nodes.csv
#   inflating: Non_Conspiracy_Graphs/275/plot.png
#   inflating: Non_Conspiracy_Graphs/276/edges.txt
#   inflating: Non_Conspiracy_Graphs/276/nodes.csv
#   inflating: Non_Conspiracy_Graphs/276/plot.png
#   inflating: Non_Conspiracy_Graphs/277/edges.txt
#   inflating: Non_Conspiracy_Graphs/277/nodes.csv
#   inflating: Non_Conspiracy_Graphs/277/plot.png
#   inflating: Non_Conspiracy_Graphs/278/edges.txt
#   inflating: Non_Conspiracy_Graphs/278/nodes.csv
#   inflating: Non_Conspiracy_Graphs/278/plot.png
#   inflating: Non_Conspiracy_Graphs/279/edges.txt
#   inflating: Non_Conspiracy_Graphs/279/nodes.csv
#   inflating: Non_Conspiracy_Graphs/279/plot.png
#   inflating: Non_Conspiracy_Graphs/28/edges.txt
#   inflating: Non_Conspiracy_Graphs/28/nodes.csv
#   inflating: Non_Conspiracy_Graphs/28/plot.png
#   inflating: Non_Conspiracy_Graphs/280/edges.txt
#   inflating: Non_Conspiracy_Graphs/280/nodes.csv
#   inflating: Non_Conspiracy_Graphs/280/plot.png
#   inflating: Non_Conspiracy_Graphs/281/edges.txt
#   inflating: Non_Conspiracy_Graphs/281/nodes.csv
#   inflating: Non_Conspiracy_Graphs/281/plot.png
#   inflating: Non_Conspiracy_Graphs/282/edges.txt
#   inflating: Non_Conspiracy_Graphs/282/nodes.csv
#   inflating: Non_Conspiracy_Graphs/282/plot.png
#   inflating: Non_Conspiracy_Graphs/283/edges.txt
#   inflating: Non_Conspiracy_Graphs/283/nodes.csv
#   inflating: Non_Conspiracy_Graphs/283/plot.png
#   inflating: Non_Conspiracy_Graphs/284/edges.txt
#   inflating: Non_Conspiracy_Graphs/284/nodes.csv
#   inflating: Non_Conspiracy_Graphs/284/plot.png
#   inflating: Non_Conspiracy_Graphs/285/edges.txt
#   inflating: Non_Conspiracy_Graphs/285/nodes.csv
#   inflating: Non_Conspiracy_Graphs/285/plot.png
#   inflating: Non_Conspiracy_Graphs/286/edges.txt
#   inflating: Non_Conspiracy_Graphs/286/nodes.csv
#   inflating: Non_Conspiracy_Graphs/286/plot.png
#   inflating: Non_Conspiracy_Graphs/287/edges.txt
#   inflating: Non_Conspiracy_Graphs/287/nodes.csv
#   inflating: Non_Conspiracy_Graphs/287/plot.png
#   inflating: Non_Conspiracy_Graphs/288/edges.txt
#   inflating: Non_Conspiracy_Graphs/288/nodes.csv
#   inflating: Non_Conspiracy_Graphs/288/plot.png
#   inflating: Non_Conspiracy_Graphs/289/edges.txt
#   inflating: Non_Conspiracy_Graphs/289/nodes.csv
#   inflating: Non_Conspiracy_Graphs/289/plot.png
#   inflating: Non_Conspiracy_Graphs/29/edges.txt
#   inflating: Non_Conspiracy_Graphs/29/nodes.csv
#   inflating: Non_Conspiracy_Graphs/29/plot.png
#   inflating: Non_Conspiracy_Graphs/290/edges.txt
#   inflating: Non_Conspiracy_Graphs/290/nodes.csv
#   inflating: Non_Conspiracy_Graphs/290/plot.png
#   inflating: Non_Conspiracy_Graphs/291/edges.txt
#   inflating: Non_Conspiracy_Graphs/291/nodes.csv
#   inflating: Non_Conspiracy_Graphs/291/plot.png
#   inflating: Non_Conspiracy_Graphs/292/edges.txt
#   inflating: Non_Conspiracy_Graphs/292/nodes.csv
#   inflating: Non_Conspiracy_Graphs/292/plot.png
#   inflating: Non_Conspiracy_Graphs/293/edges.txt
#   inflating: Non_Conspiracy_Graphs/293/nodes.csv
#   inflating: Non_Conspiracy_Graphs/293/plot.png
#   inflating: Non_Conspiracy_Graphs/294/edges.txt
#   inflating: Non_Conspiracy_Graphs/294/nodes.csv
#   inflating: Non_Conspiracy_Graphs/294/plot.png
#   inflating: Non_Conspiracy_Graphs/295/edges.txt
#   inflating: Non_Conspiracy_Graphs/295/nodes.csv
#   inflating: Non_Conspiracy_Graphs/295/plot.png
#   inflating: Non_Conspiracy_Graphs/296/edges.txt
#   inflating: Non_Conspiracy_Graphs/296/nodes.csv
#   inflating: Non_Conspiracy_Graphs/296/plot.png
#   inflating: Non_Conspiracy_Graphs/297/edges.txt
#   inflating: Non_Conspiracy_Graphs/297/nodes.csv
#   inflating: Non_Conspiracy_Graphs/297/plot.png
#   inflating: Non_Conspiracy_Graphs/298/edges.txt
#   inflating: Non_Conspiracy_Graphs/298/nodes.csv
#   inflating: Non_Conspiracy_Graphs/298/plot.png
#   inflating: Non_Conspiracy_Graphs/299/edges.txt
#   inflating: Non_Conspiracy_Graphs/299/nodes.csv
#   inflating: Non_Conspiracy_Graphs/299/plot.png
#   inflating: Non_Conspiracy_Graphs/3/edges.txt
#   inflating: Non_Conspiracy_Graphs/3/nodes.csv
#   inflating: Non_Conspiracy_Graphs/3/plot.png
#   inflating: Non_Conspiracy_Graphs/30/edges.txt
#   inflating: Non_Conspiracy_Graphs/30/nodes.csv
#   inflating: Non_Conspiracy_Graphs/30/plot.png
#   inflating: Non_Conspiracy_Graphs/300/edges.txt
#   inflating: Non_Conspiracy_Graphs/300/nodes.csv
#   inflating: Non_Conspiracy_Graphs/300/plot.png
#   inflating: Non_Conspiracy_Graphs/301/edges.txt
#   inflating: Non_Conspiracy_Graphs/301/nodes.csv
#   inflating: Non_Conspiracy_Graphs/301/plot.png
#   inflating: Non_Conspiracy_Graphs/302/edges.txt
#   inflating: Non_Conspiracy_Graphs/302/nodes.csv
#   inflating: Non_Conspiracy_Graphs/302/plot.png
#   inflating: Non_Conspiracy_Graphs/303/edges.txt
#   inflating: Non_Conspiracy_Graphs/303/nodes.csv
#   inflating: Non_Conspiracy_Graphs/303/plot.png
#   inflating: Non_Conspiracy_Graphs/304/edges.txt
#   inflating: Non_Conspiracy_Graphs/304/nodes.csv
#   inflating: Non_Conspiracy_Graphs/304/plot.png
#   inflating: Non_Conspiracy_Graphs/305/edges.txt
#   inflating: Non_Conspiracy_Graphs/305/nodes.csv
#   inflating: Non_Conspiracy_Graphs/305/plot.png
#   inflating: Non_Conspiracy_Graphs/306/edges.txt
#   inflating: Non_Conspiracy_Graphs/306/nodes.csv
#   inflating: Non_Conspiracy_Graphs/306/plot.png
#   inflating: Non_Conspiracy_Graphs/307/edges.txt
#   inflating: Non_Conspiracy_Graphs/307/nodes.csv
#   inflating: Non_Conspiracy_Graphs/307/plot.png
#   inflating: Non_Conspiracy_Graphs/308/edges.txt
#   inflating: Non_Conspiracy_Graphs/308/nodes.csv
#   inflating: Non_Conspiracy_Graphs/308/plot.png
#   inflating: Non_Conspiracy_Graphs/309/edges.txt
#   inflating: Non_Conspiracy_Graphs/309/nodes.csv
#   inflating: Non_Conspiracy_Graphs/309/plot.png
#   inflating: Non_Conspiracy_Graphs/31/edges.txt
#   inflating: Non_Conspiracy_Graphs/31/nodes.csv
#   inflating: Non_Conspiracy_Graphs/31/plot.png
#   inflating: Non_Conspiracy_Graphs/310/edges.txt
#   inflating: Non_Conspiracy_Graphs/310/nodes.csv
#   inflating: Non_Conspiracy_Graphs/310/plot.png
#   inflating: Non_Conspiracy_Graphs/311/edges.txt
#   inflating: Non_Conspiracy_Graphs/311/nodes.csv
#   inflating: Non_Conspiracy_Graphs/311/plot.png
#   inflating: Non_Conspiracy_Graphs/312/edges.txt
#   inflating: Non_Conspiracy_Graphs/312/nodes.csv
#   inflating: Non_Conspiracy_Graphs/312/plot.png
#   inflating: Non_Conspiracy_Graphs/313/edges.txt
#   inflating: Non_Conspiracy_Graphs/313/nodes.csv
#   inflating: Non_Conspiracy_Graphs/313/plot.png
#   inflating: Non_Conspiracy_Graphs/314/edges.txt
# ...
#   inflating: Other_Graphs/52/plot.png
#   inflating: Other_Graphs/520/edges.txt
#   inflating: Other_Graphs/520/nodes.csv
#   inflating: Other_Graphs/520/plot.png
#   inflating: Other_Graphs/521/edges.txt
#   inflating: Other_Graphs/521/nodes.csv
#   inflating: Other_Graphs/521/plot.png
#   inflating: Other_Graphs/522/edges.txt
#   inflating: Other_Graphs/522/nodes.csv
#   inflating: Other_Graphs/522/plot.png
#   inflating: Other_Graphs/523/edges.txt
#   inflating: Other_Graphs/523/nodes.csv
#   inflating: Other_Graphs/523/plot.png
#   inflating: Other_Graphs/524/edges.txt
#   inflating: Other_Graphs/524/nodes.csv
#   inflating: Other_Graphs/524/plot.png
#   inflating: Other_Graphs/525/edges.txt
#   inflating: Other_Graphs/525/nodes.csv
#   inflating: Other_Graphs/525/plot.png
#   inflating: Other_Graphs/526/edges.txt
#   inflating: Other_Graphs/526/nodes.csv
#   inflating: Other_Graphs/526/plot.png
#   inflating: Other_Graphs/527/edges.txt
#   inflating: Other_Graphs/527/nodes.csv
#   inflating: Other_Graphs/527/plot.png
#   inflating: Other_Graphs/528/edges.txt
#   inflating: Other_Graphs/528/nodes.csv
#   inflating: Other_Graphs/528/plot.png
#   inflating: Other_Graphs/529/edges.txt
#   inflating: Other_Graphs/529/nodes.csv
#   inflating: Other_Graphs/529/plot.png
#   inflating: Other_Graphs/53/edges.txt
#   inflating: Other_Graphs/53/nodes.csv
#   inflating: Other_Graphs/53/plot.png
#   inflating: Other_Graphs/530/edges.txt
#   inflating: Other_Graphs/530/nodes.csv
#   inflating: Other_Graphs/530/plot.png
#   inflating: Other_Graphs/531/edges.txt
#   inflating: Other_Graphs/531/nodes.csv
#   inflating: Other_Graphs/531/plot.png
#   inflating: Other_Graphs/532/edges.txt
#   inflating: Other_Graphs/532/nodes.csv
#   inflating: Other_Graphs/532/plot.png
#   inflating: Other_Graphs/533/edges.txt
#   inflating: Other_Graphs/533/nodes.csv
#   inflating: Other_Graphs/533/plot.png
#   inflating: Other_Graphs/534/edges.txt
#   inflating: Other_Graphs/534/nodes.csv
#   inflating: Other_Graphs/534/plot.png
#   inflating: Other_Graphs/535/edges.txt
#   inflating: Other_Graphs/535/nodes.csv
#   inflating: Other_Graphs/535/plot.png
#   inflating: Other_Graphs/536/edges.txt
#   inflating: Other_Graphs/536/nodes.csv
#   inflating: Other_Graphs/536/plot.png
#   inflating: Other_Graphs/537/edges.txt
#   inflating: Other_Graphs/537/nodes.csv
#   inflating: Other_Graphs/537/plot.png
#   inflating: Other_Graphs/538/edges.txt
#   inflating: Other_Graphs/538/nodes.csv
#   inflating: Other_Graphs/538/plot.png
#   inflating: Other_Graphs/539/edges.txt
#   inflating: Other_Graphs/539/nodes.csv
#   inflating: Other_Graphs/539/plot.png
#   inflating: Other_Graphs/54/edges.txt
#   inflating: Other_Graphs/54/nodes.csv
#   inflating: Other_Graphs/54/plot.png
#   inflating: Other_Graphs/540/edges.txt
#   inflating: Other_Graphs/540/nodes.csv
#   inflating: Other_Graphs/540/plot.png
#   inflating: Other_Graphs/541/edges.txt
#   inflating: Other_Graphs/541/nodes.csv
#   inflating: Other_Graphs/541/plot.png
#   inflating: Other_Graphs/542/edges.txt
#   inflating: Other_Graphs/542/nodes.csv
#   inflating: Other_Graphs/542/plot.png
#   inflating: Other_Graphs/543/edges.txt
#   inflating: Other_Graphs/543/nodes.csv
#   inflating: Other_Graphs/543/plot.png
#   inflating: Other_Graphs/544/edges.txt
#   inflating: Other_Graphs/544/nodes.csv
#   inflating: Other_Graphs/544/plot.png
#   inflating: Other_Graphs/545/edges.txt
#   inflating: Other_Graphs/545/nodes.csv
#   inflating: Other_Graphs/545/plot.png
#   inflating: Other_Graphs/546/edges.txt
#   inflating: Other_Graphs/546/nodes.csv
#   inflating: Other_Graphs/546/plot.png
#   inflating: Other_Graphs/547/edges.txt
#   inflating: Other_Graphs/547/nodes.csv
#   inflating: Other_Graphs/547/plot.png
#   inflating: Other_Graphs/548/edges.txt
#   inflating: Other_Graphs/548/nodes.csv
#   inflating: Other_Graphs/548/plot.png
#   inflating: Other_Graphs/549/edges.txt
#   inflating: Other_Graphs/549/nodes.csv
#   inflating: Other_Graphs/549/plot.png
#   inflating: Other_Graphs/55/edges.txt
#   inflating: Other_Graphs/55/nodes.csv
#   inflating: Other_Graphs/55/plot.png
#   inflating: Other_Graphs/550/edges.txt
#   inflating: Other_Graphs/550/nodes.csv
#   inflating: Other_Graphs/550/plot.png
#   inflating: Other_Graphs/551/edges.txt
#   inflating: Other_Graphs/551/nodes.csv
#   inflating: Other_Graphs/551/plot.png
#   inflating: Other_Graphs/552/edges.txt
#   inflating: Other_Graphs/552/nodes.csv
#   inflating: Other_Graphs/552/plot.png
#   inflating: Other_Graphs/553/edges.txt
#   inflating: Other_Graphs/553/nodes.csv
#   inflating: Other_Graphs/553/plot.png
#   inflating: Other_Graphs/554/edges.txt
#   inflating: Other_Graphs/554/nodes.csv
#   inflating: Other_Graphs/554/plot.png
#   inflating: Other_Graphs/555/edges.txt
#   inflating: Other_Graphs/555/nodes.csv
#   inflating: Other_Graphs/555/plot.png
#   inflating: Other_Graphs/556/edges.txt
#   inflating: Other_Graphs/556/nodes.csv
#   inflating: Other_Graphs/556/plot.png
#   inflating: Other_Graphs/557/edges.txt
#   inflating: Other_Graphs/557/nodes.csv
#   inflating: Other_Graphs/557/plot.png
#   inflating: Other_Graphs/558/edges.txt
#   inflating: Other_Graphs/558/nodes.csv
#   inflating: Other_Graphs/558/plot.png
#   inflating: Other_Graphs/559/edges.txt
#   inflating: Other_Graphs/559/nodes.csv
#   inflating: Other_Graphs/559/plot.png
#   inflating: Other_Graphs/56/edges.txt
#   inflating: Other_Graphs/56/nodes.csv
#   inflating: Other_Graphs/56/plot.png
#   inflating: Other_Graphs/560/edges.txt
#   inflating: Other_Graphs/560/nodes.csv
#   inflating: Other_Graphs/560/plot.png
#   inflating: Other_Graphs/561/edges.txt
#   inflating: Other_Graphs/561/nodes.csv
#   inflating: Other_Graphs/561/plot.png
#   inflating: Other_Graphs/562/edges.txt
#   inflating: Other_Graphs/562/nodes.csv
#   inflating: Other_Graphs/562/plot.png
#   inflating: Other_Graphs/563/edges.txt
#   inflating: Other_Graphs/563/nodes.csv
#   inflating: Other_Graphs/563/plot.png
#   inflating: Other_Graphs/564/edges.txt
#   inflating: Other_Graphs/564/nodes.csv
#   inflating: Other_Graphs/564/plot.png
#   inflating: Other_Graphs/565/edges.txt
#   inflating: Other_Graphs/565/nodes.csv
#   inflating: Other_Graphs/565/plot.png
#   inflating: Other_Graphs/566/edges.txt
#   inflating: Other_Graphs/566/nodes.csv
#   inflating: Other_Graphs/566/plot.png
#   inflating: Other_Graphs/567/edges.txt
#   inflating: Other_Graphs/567/nodes.csv
#   inflating: Other_Graphs/567/plot.png
#   inflating: Other_Graphs/568/edges.txt
#   inflating: Other_Graphs/568/nodes.csv
#   inflating: Other_Graphs/568/plot.png
#   inflating: Other_Graphs/569/edges.txt
#   inflating: Other_Graphs/569/nodes.csv
#   inflating: Other_Graphs/569/plot.png
#   inflating: Other_Graphs/57/edges.txt
#   inflating: Other_Graphs/57/nodes.csv
#   inflating: Other_Graphs/57/plot.png
#   inflating: Other_Graphs/570/edges.txt
#   inflating: Other_Graphs/570/nodes.csv
#   inflating: Other_Graphs/570/plot.png
#   inflating: Other_Graphs/571/edges.txt
#   inflating: Other_Graphs/571/nodes.csv
#   inflating: Other_Graphs/571/plot.png
#   inflating: Other_Graphs/572/edges.txt
#   inflating: Other_Graphs/572/nodes.csv
#   inflating: Other_Graphs/572/plot.png
#   inflating: Other_Graphs/573/edges.txt
#   inflating: Other_Graphs/573/nodes.csv
#   inflating: Other_Graphs/573/plot.png
#   inflating: Other_Graphs/574/edges.txt
#   inflating: Other_Graphs/574/nodes.csv
#   inflating: Other_Graphs/574/plot.png
#   inflating: Other_Graphs/575/edges.txt
#   inflating: Other_Graphs/575/nodes.csv
#   inflating: Other_Graphs/575/plot.png
#   inflating: Other_Graphs/576/edges.txt
#   inflating: Other_Graphs/576/nodes.csv
#   inflating: Other_Graphs/576/plot.png
#   inflating: Other_Graphs/577/edges.txt
#   inflating: Other_Graphs/577/nodes.csv
#   inflating: Other_Graphs/577/plot.png
#   inflating: Other_Graphs/578/edges.txt
#   inflating: Other_Graphs/578/nodes.csv
#   inflating: Other_Graphs/578/plot.png
#   inflating: Other_Graphs/579/edges.txt
#   inflating: Other_Graphs/579/nodes.csv
#   inflating: Other_Graphs/579/plot.png
#   inflating: Other_Graphs/58/edges.txt
#   inflating: Other_Graphs/58/nodes.csv
#   inflating: Other_Graphs/58/plot.png
#   inflating: Other_Graphs/580/edges.txt
#   inflating: Other_Graphs/580/nodes.csv
#   inflating: Other_Graphs/580/plot.png
#   inflating: Other_Graphs/581/edges.txt
#   inflating: Other_Graphs/581/nodes.csv
#   inflating: Other_Graphs/581/plot.png
#   inflating: Other_Graphs/582/edges.txt
#   inflating: Other_Graphs/582/nodes.csv
#   inflating: Other_Graphs/582/plot.png
#   inflating: Other_Graphs/583/edges.txt
#   inflating: Other_Graphs/583/nodes.csv
#   inflating: Other_Graphs/583/plot.png
#   inflating: Other_Graphs/584/edges.txt
#   inflating: Other_Graphs/584/nodes.csv
#   inflating: Other_Graphs/584/plot.png
#   inflating: Other_Graphs/585/edges.txt
#   inflating: Other_Graphs/585/nodes.csv
#   inflating: Other_Graphs/585/plot.png
#   inflating: Other_Graphs/586/edges.txt
#   inflating: Other_Graphs/586/nodes.csv
#   inflating: Other_Graphs/586/plot.png
#   inflating: Other_Graphs/587/edges.txt
#   inflating: Other_Graphs/587/nodes.csv
#   inflating: Other_Graphs/587/plot.png
#   inflating: Other_Graphs/588/edges.txt
#   inflating: Other_Graphs/588/nodes.csv
#   inflating: Other_Graphs/588/plot.png
#   inflating: Other_Graphs/589/edges.txt
#   inflating: Other_Graphs/589/nodes.csv
#   inflating: Other_Graphs/589/plot.png
#   inflating: Other_Graphs/59/edges.txt
#   inflating: Other_Graphs/59/nodes.csv
#   inflating: Other_Graphs/59/plot.png
#   inflating: Other_Graphs/590/edges.txt
#   inflating: Other_Graphs/590/nodes.csv
#   inflating: Other_Graphs/590/plot.png
#   inflating: Other_Graphs/591/edges.txt
#   inflating: Other_Graphs/591/nodes.csv
#   inflating: Other_Graphs/591/plot.png
#   inflating: Other_Graphs/592/edges.txt
#   inflating: Other_Graphs/592/nodes.csv
#   inflating: Other_Graphs/592/plot.png
#   inflating: Other_Graphs/593/edges.txt
#   inflating: Other_Graphs/593/nodes.csv
#   inflating: Other_Graphs/593/plot.png
#   inflating: Other_Graphs/594/edges.txt
#   inflating: Other_Graphs/594/nodes.csv
#   inflating: Other_Graphs/594/plot.png
#   inflating: Other_Graphs/595/edges.txt
#   inflating: Other_Graphs/595/nodes.csv
#   inflating: Other_Graphs/595/plot.png
#   inflating: Other_Graphs/596/edges.txt
#   inflating: Other_Graphs/596/nodes.csv
#   inflating: Other_Graphs/596/plot.png
#   inflating: Other_Graphs/597/edges.txt
#   inflating: Other_Graphs/597/nodes.csv
#   inflating: Other_Graphs/597/plot.png
#   inflating: Other_Graphs/6/edges.txt
#   inflating: Other_Graphs/6/nodes.csv
#   inflating: Other_Graphs/6/plot.png
#   inflating: Other_Graphs/60/edges.txt
#   inflating: Other_Graphs/60/nodes.csv
#   inflating: Other_Graphs/60/plot.png
#   inflating: Other_Graphs/61/edges.txt
#   inflating: Other_Graphs/61/nodes.csv
#   inflating: Other_Graphs/61/plot.png
#   inflating: Other_Graphs/62/edges.txt
#   inflating: Other_Graphs/62/nodes.csv
#   inflating: Other_Graphs/62/plot.png
#   inflating: Other_Graphs/63/edges.txt
#   inflating: Other_Graphs/63/nodes.csv
#   inflating: Other_Graphs/63/plot.png
#   inflating: Other_Graphs/64/edges.txt
#   inflating: Other_Graphs/64/nodes.csv
#   inflating: Other_Graphs/64/plot.png
#   inflating: Other_Graphs/65/edges.txt
#   inflating: Other_Graphs/65/nodes.csv
#   inflating: Other_Graphs/65/plot.png
#   inflating: Other_Graphs/66/edges.txt
#   inflating: Other_Graphs/66/nodes.csv
#   inflating: Other_Graphs/66/plot.png
#   inflating: Other_Graphs/67/edges.txt
#   inflating: Other_Graphs/67/nodes.csv
#   inflating: Other_Graphs/67/plot.png
#   inflating: Other_Graphs/68/edges.txt
#   inflating: Other_Graphs/68/nodes.csv
#   inflating: Other_Graphs/68/plot.png
#   inflating: Other_Graphs/69/edges.txt
#   inflating: Other_Graphs/69/nodes.csv
#   inflating: Other_Graphs/69/plot.png
#   inflating: Other_Graphs/7/edges.txt
#   inflating: Other_Graphs/7/nodes.csv
#   inflating: Other_Graphs/7/plot.png
#   inflating: Other_Graphs/70/edges.txt
#   inflating: Other_Graphs/70/nodes.csv
#   inflating: Other_Graphs/70/plot.png
#   inflating: Other_Graphs/71/edges.txt
#   inflating: Other_Graphs/71/nodes.csv
#   inflating: Other_Graphs/71/plot.png
#   inflating: Other_Graphs/72/edges.txt
#   inflating: Other_Graphs/72/nodes.csv
#   inflating: Other_Graphs/72/plot.png
#   inflating: Other_Graphs/73/edges.txt
#   inflating: Other_Graphs/73/nodes.csv
#   inflating: Other_Graphs/73/plot.png
#   inflating: Other_Graphs/74/edges.txt
#   inflating: Other_Graphs/74/nodes.csv
#   inflating: Other_Graphs/74/plot.png
#   inflating: Other_Graphs/75/edges.txt
#   inflating: Other_Graphs/75/nodes.csv
#   inflating: Other_Graphs/75/plot.png
#   inflating: Other_Graphs/76/edges.txt
#   inflating: Other_Graphs/76/nodes.csv
#   inflating: Other_Graphs/76/plot.png
#   inflating: Other_Graphs/77/edges.txt
#   inflating: Other_Graphs/77/nodes.csv
#   inflating: Other_Graphs/77/plot.png
#   inflating: Other_Graphs/78/edges.txt
#   inflating: Other_Graphs/78/nodes.csv
#   inflating: Other_Graphs/78/plot.png
#   inflating: Other_Graphs/79/edges.txt
#   inflating: Other_Graphs/79/nodes.csv
#   inflating: Other_Graphs/79/plot.png
#   inflating: Other_Graphs/8/edges.txt
#   inflating: Other_Graphs/8/nodes.csv
#   inflating: Other_Graphs/8/plot.png
#   inflating: Other_Graphs/80/edges.txt
#   inflating: Other_Graphs/80/nodes.csv
#   inflating: Other_Graphs/80/plot.png
#   inflating: Other_Graphs/81/edges.txt
#   inflating: Other_Graphs/81/nodes.csv
#   inflating: Other_Graphs/81/plot.png
#   inflating: Other_Graphs/82/edges.txt
#   inflating: Other_Graphs/82/nodes.csv
#   inflating: Other_Graphs/82/plot.png
#   inflating: Other_Graphs/83/edges.txt
#   inflating: Other_Graphs/83/nodes.csv
#   inflating: Other_Graphs/83/plot.png
#   inflating: Other_Graphs/84/edges.txt
#   inflating: Other_Graphs/84/nodes.csv
#   inflating: Other_Graphs/84/plot.png
#   inflating: Other_Graphs/85/edges.txt
#   inflating: Other_Graphs/85/nodes.csv
#   inflating: Other_Graphs/85/plot.png
#   inflating: Other_Graphs/86/edges.txt
#   inflating: Other_Graphs/86/nodes.csv
#   inflating: Other_Graphs/86/plot.png
#   inflating: Other_Graphs/87/edges.txt
#   inflating: Other_Graphs/87/nodes.csv
#   inflating: Other_Graphs/87/plot.png
#   inflating: Other_Graphs/88/edges.txt
#   inflating: Other_Graphs/88/nodes.csv
#   inflating: Other_Graphs/88/plot.png
#   inflating: Other_Graphs/89/edges.txt
#   inflating: Other_Graphs/89/nodes.csv
#   inflating: Other_Graphs/89/plot.png
#   inflating: Other_Graphs/9/edges.txt
#   inflating: Other_Graphs/9/nodes.csv
#   inflating: Other_Graphs/9/plot.png
#   inflating: Other_Graphs/90/edges.txt
#   inflating: Other_Graphs/90/nodes.csv
#   inflating: Other_Graphs/90/plot.png
#   inflating: Other_Graphs/91/edges.txt
#   inflating: Other_Graphs/91/nodes.csv
#   inflating: Other_Graphs/91/plot.png
#   inflating: Other_Graphs/92/edges.txt
#   inflating: Other_Graphs/92/nodes.csv
#   inflating: Other_Graphs/92/plot.png
#   inflating: Other_Graphs/93/edges.txt
#   inflating: Other_Graphs/93/nodes.csv
#   inflating: Other_Graphs/93/plot.png
#   inflating: Other_Graphs/94/edges.txt
#   inflating: Other_Graphs/94/nodes.csv
#   inflating: Other_Graphs/94/plot.png
#   inflating: Other_Graphs/95/edges.txt
#   inflating: Other_Graphs/95/nodes.csv
#   inflating: Other_Graphs/95/plot.png
#   inflating: Other_Graphs/96/edges.txt
#   inflating: Other_Graphs/96/nodes.csv
#   inflating: Other_Graphs/96/plot.png
#   inflating: Other_Graphs/97/edges.txt
#   inflating: Other_Graphs/97/nodes.csv
#   inflating: Other_Graphs/97/plot.png
#   inflating: Other_Graphs/98/edges.txt
#   inflating: Other_Graphs/98/nodes.csv
#   inflating: Other_Graphs/98/plot.png
#   inflating: Other_Graphs/99/edges.txt
#   inflating: Other_Graphs/99/nodes.csv
#   inflating: Other_Graphs/99/plot.png

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import random
import networkx as nx
import pandas as pd
import os
import statistics
import matplotlib.pyplot as plt
import numpy as np

def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %% [markdown]
# ### Extracting 5G Conspiracy Graphs

# %%
temp = []

for i in range(1,413):
    temp.append(list_files(f'5G_Conspiracy_Graphs/{i}/'))

five_cons = []
for i in range(len(temp)):
  nodes = [k for k in temp[i] if 'nodes' in k][0]
  n = pd.read_csv(nodes,sep=",")
  s_node = [n['id'][k] for k in range(n.shape[0]) if n['time'][k] == 0][0]

  for j in range(len(temp[i])):
    if 'edges' in temp[i][j]:
      break
  f = pd.read_csv(temp[i][j],sep=" ",names=['source','target'])
  f['rumor_source'] = 0
  f.loc[f["source"] == s_node, "rumor_source"] = 1
  g = nx.from_pandas_edgelist(f,source='source', target='target',create_using = nx.DiGraph)
  five_cons.append((g,s_node))

# %% [markdown]
# ### Extracting Other Conspiracy Graphs

# %%
temp = []

for i in range(1,598):
    temp.append(list_files(f'Other_Graphs/{i}/'))

other_cons = []
for i in range(len(temp)):
  nodes = [k for k in temp[i] if 'nodes' in k][0]
  n = pd.read_csv(nodes,sep=",")
  s_node = [n['id'][k] for k in range(n.shape[0]) if n['time'][k] == 0][0]

  for j in range(len(temp[i])):
    if 'edges' in temp[i][j]:
      break
  f = pd.read_csv(temp[i][j],sep=" ",names=['source','target'])
  f['rumor_source'] = 0
  g = nx.from_pandas_edgelist(f,source='source', target='target',create_using = nx.DiGraph)
  other_cons.append((g,s_node))

# %% [markdown]
# ### Extracting Non-Conspiracy Graphs

# %%
temp = []

for i in range(1,2502):
    temp.append(list_files(f'Non_Conspiracy_Graphs/{i}/'))

non_cons = []
for i in range(len(temp)):
  nodes = [k for k in temp[i] if 'nodes' in k][0]
  n = pd.read_csv(nodes,sep=",")
  s_node = [n['id'][k] for k in range(n.shape[0]) if n['time'][k] == 0][0]

  for j in range(len(temp[i])):
    if 'edges' in temp[i][j]:
      break
  f = pd.read_csv(temp[i][j],sep=" ",names=['source','target'])
  f['rumor_source'] = 0
  g = nx.from_pandas_edgelist(f,source='source', target='target',create_using = nx.DiGraph)
  non_cons.append((g,s_node))

# %%
from sklearn.metrics import accuracy_score
import math
import numpy as np

# %% [markdown]
# ## Rumor Centrality
#
# - The rumor centrality of a node is described as a number of
# definite propagation paths starting from the origin node. `The node
# having higher rumor centrality is the source of information propagation.`
# <br/>
# - For general network, the original network graph is converted into a
# tree referred as a BFS tree using Breadth First Search (BFS) technique, in which any node in the graph assumed as source node is
# considered as starting node for BFS.
#
# - Given node u ∈ V in graph G =
# (V,E), let T ⊂ G denote the breadth-first search tree of u with
# respect to G. Then, the rumor centrality of u with respect to G
# is obtained by computing it as per Equation 2.1 with respect to T, where $T_w^u$ is the size of the subtree of G that is rooted at w and
# points away from u.
#
# - The estimated rumor source is the one with maximal rumor centrality
# (ties broken uniformly at random).
#
# <img src="http://drive.google.com/uc?export=view&id=189k6T_7btzanNAxHKI3CFobxV9alOlyx">

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  count = 1
  node_rc = []
  for j in i[0]:

    #We calculate the bfs tree for each node in the graph to calculate the rumor centrality for each of the node.

    t = nx.bfs_tree(i[0],source=j)

    '''Calculating all the tree sizes for the denominator of the formula.
       We take the dfs at every node to calculate the size of the graph starting at that node and pointing away from j.    
    '''

    T = []
    for k in list(t):
      T.append(len(list(nx.dfs_tree(t,source = k))))

    #Calculating Rumor Centrality as per formula 2.1

    rc = math.factorial(len(list(t)))/(np.prod(T))
    node_rc.append([j,rc])

    #Selecting the nodes that have maximum rumor centrality.
  try:
    max_rc = sorted(node_rc,key = lambda x : x[1],reverse = True)[0][1]
    calc_source.append([i[0] for i in node_rc if i[1] == max_rc])
  except:
    calc_source.append([])

    #Calculating the accuracy score of the metric to see if it could identify the actual source node in its predicted sources.
count = 0
for i in range(len(calc_source)):
  if real_source[i] in calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.27184466019417475

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  count = 1
  node_rc = []
  for j in i[0]:
    t = nx.bfs_tree(i[0],source=j)
    T = []
    for k in list(t):
      T.append(len(list(nx.dfs_tree(t,source = k))))
    rc = math.factorial(len(list(t)))/(np.prod(T))
    node_rc.append([j,rc])
  try:
    max_rc = sorted(node_rc,key = lambda x : x[1],reverse = True)[0][1]
    calc_source.append([i[0] for i in node_rc if i[1] == max_rc])
  except:
    calc_source.append([])

count = 0
for i in range(len(calc_source)):
  if real_source[i] in calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.21273031825795644

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  count = 1
  node_rc = []
  for j in i[0]:
    t = nx.bfs_tree(i[0],source=j)
    T = []
    for k in list(t):
      T.append(len(list(nx.dfs_tree(t,source = k))))
    rc = math.factorial(len(list(t)))/(np.prod(T))
    node_rc.append([j,rc])
  try:
    max_rc = sorted(node_rc,key = lambda x : x[1],reverse = True)[0][1]
    calc_source.append([i[0] for i in node_rc if i[1] == max_rc])
  except:
    calc_source.append([])

count = 0
for i in range(len(calc_source)):
  if real_source[i] in calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.18072770891643342

# %% [markdown]
# ## Closeness Centrality
#
# - The node with the highest closeness centrality in the largest weakly connected network is taken as the possible rumor node.

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest clustering coefficient.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.7233009708737864

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  try:
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.7939698492462312

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  try:
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.8128748500599761

# %% [markdown]
# ## Jordan Center
#
# - For each vertex $V$ you have to find $V_m$ - the largest distance to any other vertex amongst the data returned from All pairs shortest path (Dijkstra). Then, the vertex with the smallest $V_m$ are the one in the graph center (Jordan Center).

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  jordan = []
  
  #Calculating all the shortest paths from a vertex to all other nodes and taking the maximum shortest path.
  max_cc = max(nx.weakly_connected_components(i[0]), key=len)
  cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))
  for j in nx.all_pairs_shortest_path(cc_l):
    jordan.append([j[0],max([len(k) for k in j[1].values()])])
  
  #Taking the node with the shortest maximum distance to other nodes.
  
  try:
    calc_source.append(sorted(jordan,key = lambda x: x[1])[0][0])
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.3422330097087379

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  jordan = []
  for j in nx.all_pairs_shortest_path(i[0]):
    jordan.append([j[0],max([len(k) for k in j[1].values()])])
  try:
    calc_source.append(sorted(jordan,key = lambda x: x[1])[0][0])
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.33835845896147404

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  jordan = []
  for j in nx.all_pairs_shortest_path(i[0]):
    jordan.append([j[0],max([len(k) for k in j[1].values()])])
  try:
    calc_source.append(sorted(jordan,key = lambda x: x[1])[0][0])
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5041983206717313

# %% [markdown]
# ## Voronoi Cells (Modified)
#
# - We first take the largest weakly connected component.
# - Then we take 5 nodes with highest closeness centrality.
# - Finally, we take the Voronoi Partition of each node in the top 2 nodes,
#   and select the rumor node as the one with the largest partition size.

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  v_centres = []
  try:

    #calculating the largest weakly connected component to find closeness centrality.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))

    #Using the top 5 highest clustering coefficients as veronoi centres.

    for k, v in cc_l.items():
      v_centres.append([k,v])
    v_centres = sorted(v_centres,key = lambda x: x[1],reverse = True)
    v_centres = [k[0] for k in v_centres][:2]
  except:
    v_centres = []
  if v_centres != []:
    
    #Calculating the size of vornoi partitions and choosing the centre corresponding to the highest size of partition.
    
    v_cells = nx.voronoi_cells(i[0],v_centres)
    v_cells.pop('unreachable', None)
    calc_source.append(max(v_cells, key=lambda x: len(v_cells[x])))
  else:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5558252427184466

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  v_centres = []
  try:
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))
    for k, v in cc_l.items():
      v_centres.append([k,v])
    v_centres = sorted(v_centres,key = lambda x: x[1],reverse = True)
    v_centres = [k[0] for k in v_centres][:2]
  except:
    v_centres = []
  if v_centres != []:
    v_cells = nx.voronoi_cells(i[0],v_centres)
    v_cells.pop('unreachable', None)
    calc_source.append(max(v_cells, key=lambda x: len(v_cells[x])))
  else:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.52428810720268

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  v_centres = []
  try:
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.closeness_centrality(i[0].subgraph(list(max_cc)))
    for k, v in cc_l.items():
      v_centres.append([k,v])
    v_centres = sorted(v_centres,key = lambda x: x[1])
    v_centres = [k[0] for k in v_centres][:2]
  except:
    v_centres = []
  if v_centres != []:
    v_cells = nx.voronoi_cells(i[0],v_centres)
    v_cells.pop('unreachable', None)
    calc_source.append(max(v_cells, key=lambda x: len(v_cells[x])))
  else:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.001599360255897641

# %% [markdown]
# ## Epidemic Center (Modified)
#
# - We take the largest weakly connected component.
# - Then we calculate the cycles basis and find the node that appears in most cycles. Ties are broken with degree of nodes.

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  g = i[0]
  try:

    #Taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(g), key=len)
    g = g.subgraph(list(max_cc))

    #Convert the component into undirectional and take the cycle basis.
    
    g = g.to_undirected()
    cycles = nx.cycle_basis(g)

    d_nodes = {}
    for c in cycles:
      for n in c:
        if n in d_nodes:
          d_nodes[n] += 1
        else:
          d_nodes[n] = 1
    l_nodes = []

    #We use degree to break ties.

    for d in d_nodes:
      l_nodes.append([d,d_nodes[d],g.degree(d)])
    l_nodes = sorted(l_nodes, key = lambda x : (x[1],x[2]), reverse = True)
    try:
      calc_source.append(l_nodes[0][0])
    except:
      calc_source.append(-1)
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.4077669902912621

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  g = i[0]
  try:
    max_cc = max(nx.weakly_connected_components(g), key=len)
    g = g.subgraph(list(max_cc))
    g = g.to_undirected()
    cycles = nx.cycle_basis(g)
    d_nodes = {}
    for c in cycles:
      for n in c:
        if n in d_nodes:
          d_nodes[n] += 1
        else:
          d_nodes[n] = 1
    l_nodes = []
    for d in d_nodes:
      l_nodes.append([d,d_nodes[d],g.degree(d)])
    l_nodes = sorted(l_nodes, key = lambda x : (x[1],x[2]), reverse = True)
    try:
      calc_source.append(l_nodes[0][0])
    except:
      calc_source.append(-1)
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5678391959798995

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  g = i[0]
  try:
    max_cc = max(nx.weakly_connected_components(g), key=len)
    g = g.subgraph(list(max_cc))
    g = g.to_undirected()
    cycles = nx.cycle_basis(g)
    d_nodes = {}
    for c in cycles:
      for n in c:
        if n in d_nodes:
          d_nodes[n] += 1
        else:
          d_nodes[n] = 1
    l_nodes = []
    for d in d_nodes:
      l_nodes.append([d,d_nodes[d],g.degree(d)])
    l_nodes = sorted(l_nodes, key = lambda x : (x[1],x[2]), reverse = True)
    try:
      calc_source.append(l_nodes[0][0])
    except:
      calc_source.append(-1)
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5133946421431428

# %% [markdown]
# ## Betweenness Centrality

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.betweenness_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest betweenness centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.49271844660194175

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.betweenness_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest betweenness centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.48576214405360135

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.betweenness_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest betweenness centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.3678528588564574

# %% [markdown]
# ## Eigenvector Centrality

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.eigenvector_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5970873786407767

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.eigenvector_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.6314907872696818

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  try:
    #taking the largest weakly connected component.

    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = nx.eigenvector_centrality(i[0].subgraph(list(max_cc)))

    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.5605757696921232

# %% [markdown]
# ## DC + CC
#
# - Degree Centrality + Closeness Centrality
# - DC+CC is a combination of degree centrality and closeness centrality. In DC+CC, first DC
# (degree centrality) selects nodes with highest degree in the infection graph G (V, E).
# - Then CC (closeness centrality) picks
# the node with highest closeness centrality rank among the nodes
# selected by DC. This node, finally, is considered as the source.
# - Formally, the source estimated by DC+CC is given as:<br/>
#   `DC+CC = $argmax_w$($argmax_u$($degree(u)$)), w∈u, u∈V`

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    d_l = nx.in_degree_centrality(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with highest degree centrality.
    for k, v in d_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1],reverse = True)
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.7233009708737864

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    d_l = nx.in_degree_centrality(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with highest degree centrality.
    for k, v in d_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1],reverse = True)
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.7973199329983249

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    d_l = nx.degree_centrality(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with highest degree centrality.
    for k, v in d_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1],reverse = True)
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.8092762894842063

# %% [markdown]
# ## EC + CC
#
# - Eccentricity + Closeness Centrality
# - EC+CC is a combination of eccentricity and closeness centrality. In EC+CC, first EC (eccentricity) selects the nodes with minimum eccentricity in the infection graph G (V, E).
# - Then CC (closeness centrality) picks
# the node with highest closeness centrality rank among the nodes
# selected by EC. This node, finally, is considered as the source.
# - Formally, the source estimated by EC+CC is given as:<br/>
#   `EC+CC = $argmax_w$($argmin_u$($eccentricity(u)$)), w∈u, u∈V`

# %%
calc_source = []
real_source = [i[1] for i in five_cons]

for i in five_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    e_l = nx.eccentricity(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with lowest eccentricity.
    for k, v in e_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1])
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.06796116504854369

# %%
calc_source = []
real_source = [i[1] for i in other_cons]

for i in other_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    e_l = nx.eccentricity(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with lowest eccentricity.
    for k, v in e_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1])
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.03015075376884422

# %%
calc_source = []
real_source = [i[1] for i in non_cons]

for i in non_cons:
  try:
    #taking the largest weakly connected component.
    p_centres = []
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    e_l = nx.eccentricity(i[0].subgraph(list(max_cc)))

    #taking the 10 nodes with lowest eccentricity.
    for k, v in e_l.items():
      p_centres.append([k,v])
    p_centres = sorted(p_centres,key = lambda x: x[1])
    p_centres = [k[0] for k in p_centres][:10]

    #finding the node with maximum closeness centrality among the nodes selected by degree centrality
    max_cc = max(nx.weakly_connected_components(i[0]), key=len)
    cc_l = {}
    for j in p_centres:
      cc_l[j] = nx.closeness_centrality(i[0].subgraph(list(max_cc)),j)
    #getting the node with the largest eigenvector centrality.
    
    calc_source.append(max(cc_l, key=cc_l.get))
  except:
    calc_source.append(-1)

count = 0
for i in range(len(calc_source)):
  if real_source[i] == calc_source[i]:
    count += 1
print(count/len(real_source))
# Out:
# 0.02958816473410636
